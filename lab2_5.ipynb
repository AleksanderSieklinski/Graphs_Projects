# %%
from graph_lib import MyGraph
 
nValue = 10 # number of vertices
kValue = 2 # degree

generatedGraph = MyGraph.generateKRegularGraph(nValue, kValue, 1)
if generatedGraph is not None:
    generatedGraph.showGraph()
# Out:
# [[0, 6], [1, 6], [2, 6], [3, 6], [4, 6], [5, 6], [6, 6], [7, 6], [8, 6], [9, 6]]
# [[7, 6], [8, 6], [9, 6], [1, 5], [2, 5], [3, 5], [4, 5], [5, 5], [6, 5], [0, 0]]
# [[8, 5], [9, 5], [5, 5], [6, 5], [1, 4], [2, 4], [3, 4], [4, 4], [7, 0], [0, 0]]
# [[9, 4], [5, 4], [6, 4], [3, 4], [4, 4], [1, 3], [2, 3], [8, 0], [7, 0], [0, 0]]
# [[5, 3], [6, 3], [3, 3], [4, 3], [1, 3], [2, 3], [9, 0], [8, 0], [7, 0], [0, 0]]
# [[1, 3], [2, 3], [6, 2], [3, 2], [4, 2], [5, 0], [9, 0], [8, 0], [7, 0], [0, 0]]
# [[2, 2], [4, 2], [6, 1], [3, 1], [1, 0], [5, 0], [9, 0], [8, 0], [7, 0], [0, 0]]
# [[4, 1], [3, 1], [2, 0], [6, 0], [1, 0], [5, 0], [9, 0], [8, 0], [7, 0], [0, 0]]
# [[4, 0], [3, 0], [2, 0], [6, 0], [1, 0], [5, 0], [9, 0], [8, 0], [7, 0], [0, 0]]
